# %%
pip install pycaret
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 483.9/483.9 kB 6.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 44.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.4/153.4 kB 16.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.8/81.8 kB 8.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 18.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 9.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 11.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 kB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 76.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 4.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 82.8 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
from pycaret.classification import *

# %%
df = pd.read_csv('/content/labelled_crypto_data.csv')

# %%
df.head()
# Out:
#                                                 news        date Sentiment
# 0  bitcoin priced usd mt goxabove gox price pm gm...  2017-08-15   Neutral
# 1  bitcoin price fib level dmas ok last week like...  2017-05-12   Bullish
# 2  national australia bank loom melbourne citizen...  2017-09-19   Neutral
# 3  recent report china indicate may bitcoin ban m...  2014-10-03   Bullish
# 4  opened st bitcoin trade position price current...  2016-01-15   Neutral

# %%
df = df.drop(["date"],axis =1)
df = df.dropna()
df
# The df_clean DataFrame will now contain rows with no missing values
# Out:
#                                                     news Sentiment
# 0      bitcoin priced usd mt goxabove gox price pm gm...   Neutral
# 1      bitcoin price fib level dmas ok last week like...   Bullish
# 2      national australia bank loom melbourne citizen...   Neutral
# 3      recent report china indicate may bitcoin ban m...   Bullish
# 4      opened st bitcoin trade position price current...   Neutral
# ...                                                  ...       ...
# 37508                             market caught tugofwar   Neutral
# 37509  market weekly outlook bitcoin altcoins bounce ...   Neutral
# 37510                bitcoin altcoins consolidating loss   Neutral
# 37511        bitcoin altcoins pressure despite consensus   Neutral
# 37512                    bitcoin altcoins rally unravels   Neutral
#
# [37513 rows x 2 columns]

# %%
df['label'] = df['Sentiment'].map({
    'Bullish' : 0,
    'Neutral': 1,
    'Bearish': 2,
})
df = df.drop(["Sentiment"],axis =1)
df.sample(5)
# Out:
#                                                     news  label
# 16505  cgi launched lab dedicated helping trade finan...      1
# 24918  blockchain initiative backed dozen u credit un...      1
# 10311  much ashley madison customer blackmailed since...      1
# 16606  digital asset holding announced intends openso...      1
# 10147  goldman sachs filed patent application last mo...      0

# %%
experiment = setup(df, target='label', categorical_features=['news'])
# Out:
# <style type="text/css">
# #T_9c1c0_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_9c1c0" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9c1c0_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_9c1c0_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9c1c0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9c1c0_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_9c1c0_row0_col1" class="data row0 col1" >8689</td>
#     </tr>
#     <tr>
#       <th id="T_9c1c0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9c1c0_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_9c1c0_row1_col1" class="data row1 col1" >label</td>
#     </tr>
#     <tr>
#       <th id="T_9c1c0_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_e4dc6 th {
#   text-align: left;
# }
# ...
